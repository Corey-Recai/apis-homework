# %%
# Import Modules
import os
import plaid
import requests
import datetime
import pendulum
import json
import pandas as pd
# %matplotlib inline

# %%
# Define JSON prettifier parameters
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Read API keys in from txt files
file1 = open('./keys/plaid_client_id.txt','r')
plaid_client_id = file1.readline()
file1.close()

file2 = open('./keys/plaid_secret.txt','r')
plaid_secret = file2.readline()
file2.close()

file3 = open('./keys/plaid_public_key.txt','r')
plaid_public_key = file3.readline()
file3.close()

# %%
# Set Plaid environment variables
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID', plaid_client_id)
PLAID_SECRET = os.getenv('PLAID_SECRET', plaid_secret)
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY', plaid_public_key)
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Set Plaid Institition ID
INSTITUTION_ID = "ins_109508"

# %%
# Set Plaid development environment
client = plaid.Client(client_id = PLAID_CLIENT_ID, 
                      secret=PLAID_SECRET,
                      public_key=PLAID_PUBLIC_KEY, 
                      environment=PLAID_ENV, 
                      api_version='2019-05-29')

# %% [markdown]
# ### 2. Generate a public token

# %%
# create response from sandbox - detailed in plaid api documentation
create_response = client.Sandbox.public_token.create(
    INSTITUTION_ID, ['transactions'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Set access token from exchange response
response = client.Item.public_token.exchange(create_response['public_token'])
access_token = response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Create call response for Accounts
accounts_response = client.Accounts.get(access_token)

# %%
# Fetch Accounts
accounts = accounts_response['accounts']
pretty_print_response(accounts[:3])
# Out:
# [
#     {
#         "account_id": "EAwd1pAn7GFbAjqvbDjKsxGMpMp6jwtX8A8o6",
#         "balances": {
#             "available": 100,
#             "current": 110,
#             "iso_currency_code": "USD",
#             "limit": null,
#             "unofficial_currency_code": null
#         },
#         "mask": "0000",
#         "name": "Plaid Checking",
#         "official_name": "Plaid Gold Standard 0% Interest Checking",
#         "subtype": "checking",
#         "type": "depository"
#     },
#     {
#         "account_id": "WZLWd7ZpJvcBQd17BodGiMoQrQr6XdIl3N3px",
#         "balances": {
#             "available": 200,
#             "current": 210,
#             "iso_currency_code": "USD",
#             "limit": null,
#             "unofficial_currency_code": null
#         },
#         "mask": "1111",
#         "name": "Plaid Saving",
#         "official_name": "Plaid Silver Standard 0.1% Interest Saving",
#         "subtype": "savings",
#         "type": "depository"
#     },
#     {
#         "account_id": "AgxzeZg418tyJazbyNa1TNjkGkGqgEF1LVLg3",
#         "balances": {
#             "available": null,
#             "current": 1000,
#             "iso_currency_code": "USD",
#             "limit": null,
#             "unofficial_currency_code": null
#         },
#         "mask": "2222",
#         "name": "Plaid CD",
#         "official_name": "Plaid Bronze Standard 0.2% Interest CD",
#         "subtype": "cd",
#         "type": "depository"
#     }
# ]

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set start date and end date for data
start_date = pendulum.now().subtract(days=90).to_date_string()
end_date = pendulum.now().to_date_string()

# %%
# Create a call response for transactions
transactions_response = client.Transactions.get(
    access_token,
    start_date = start_date,
    end_date = end_date,
)

# %%
# Fetch Transactions
transactions = transactions_response['transactions']
pretty_print_response(transactions[:3])
# Out:
# [
#     {
#         "account_id": "EAwd1pAn7GFbAjqvbDjKsxGMpMp6jwtX8A8o6",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-05-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "mNgjqGNaJdCNabr7NRbBFMAQba5NENuLD1nWW",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "WZLWd7ZpJvcBQd17BodGiMoQrQr6XdIl3N3px",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-05-10",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "XMgAaeMQovTjZmLwjgmkIkGamrN8e8HdmeN3v",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "Gqy4pgqRwvhXlerwXLeNc5eL1L1xXqh1KNKbj",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-04-30",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "wpbkNGpx3MFp1QlzpaQBSqwV1m6494HrbWx5Z",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     }
# ]

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Render data into DataFrame and print 'category' and 'transaction_id' columns
transactions_df = pd.DataFrame(transactions)
transactions_df[['category','transaction_id']]
# Out:
#                                       category  \
# 0                [Food and Drink, Restaurants]
# 1                           [Transfer, Credit]
# 2     [Travel, Airlines and Aviation Services]
# 3                               [Travel, Taxi]
# 4                [Food and Drink, Restaurants]
# 5                                    [Payment]
# 6     [Food and Drink, Restaurants, Fast Food]
# 7                      [Shops, Sporting Goods]
# 8                       [Payment, Credit Card]
# 9                               [Travel, Taxi]
# 10                           [Transfer, Debit]
# 11                         [Transfer, Deposit]
# 12      [Recreation, Gyms and Fitness Centers]
# 13    [Travel, Airlines and Aviation Services]
# 14    [Food and Drink, Restaurants, Fast Food]
# 15  [Food and Drink, Restaurants, Coffee Shop]
# 16               [Food and Drink, Restaurants]
# 17                          [Transfer, Credit]
# 18    [Travel, Airlines and Aviation Services]
# 19                              [Travel, Taxi]
# 20               [Food and Drink, Restaurants]
# 21                                   [Payment]
# 22    [Food and Drink, Restaurants, Fast Food]
# 23                     [Shops, Sporting Goods]
# 24                      [Payment, Credit Card]
# 25                              [Travel, Taxi]
# 26                           [Transfer, Debit]
# 27                         [Transfer, Deposit]
# 28      [Recreation, Gyms and Fitness Centers]
# 29    [Travel, Airlines and Aviation Services]
# 30    [Food and Drink, Restaurants, Fast Food]
# 31  [Food and Drink, Restaurants, Coffee Shop]
# 32               [Food and Drink, Restaurants]
# 33                          [Transfer, Credit]
# 34    [Travel, Airlines and Aviation Services]
# 35                              [Travel, Taxi]
# 36               [Food and Drink, Restaurants]
# 37                                   [Payment]
# 38    [Food and Drink, Restaurants, Fast Food]
# 39                     [Shops, Sporting Goods]
# 40                      [Payment, Credit Card]
# 41                              [Travel, Taxi]
# 42                           [Transfer, Debit]
# 43                         [Transfer, Deposit]
# 44      [Recreation, Gyms and Fitness Centers]
# 45    [Travel, Airlines and Aviation Services]
# 46    [Food and Drink, Restaurants, Fast Food]
# 47  [Food and Drink, Restaurants, Coffee Shop]
# 48               [Food and Drink, Restaurants]
#
#                            transaction_id
# 0   mNgjqGNaJdCNabr7NRbBFMAQba5NENuLD1nWW
# 1   XMgAaeMQovTjZmLwjgmkIkGamrN8e8HdmeN3v
# 2   wpbkNGpx3MFp1QlzpaQBSqwV1m6494HrbWx5Z
# 3   ygMEjXgDdLtGnp85GNpgSbg9EkQdZdtyzEblb
# 4   5N4ArBNJ7PCwnk8ywvkQSN38a9moMoCZ1NAWr
# 5   l49PlG4J7xF4d9Wn4P9yFEQRxarvDvfZVbekX
# 6   kaxNG6apw3C9xeX49NeRUynPJdbe1eFWlZeXb
# 7   Jz4j8qzQkvcdrM3wdoMWUMvGV8BD6DudDRv9D
# 8   DW1kMLW4oATDePl1DLPntQ5rmyBgbgfv56BkN
# 9   9edmxae5kQfkgqzDkrqWs5G3b4wLjLCRpZw5a
# 10  KB47EKByRvuaz1xdaD1mhMRjP4W1e1uVxzaLy
# 11  VQaExjQwpvcLenMBLWnvcjDr69bQEQiWBKXwy
# 12  qebZBGeqlPfeJN9GerNyUN8rJXqmGmCdzw1Za
# 13  vLMo4wL3BZtme7gqmd7wInVp1lDxGxCWM8BEk
# 14  RPQpraPZBvCBNr7DB1rLineByQWNpNCRgnWB4
# 15  6PeGz3PLXjCe68p4eo8GUv9NaEAWLWugBdpye
# 16  AgxzeZg418tyJazbyNa1TNjLmygLQqF1ABazX
# 17  erPBoGry6ltrJo9XrBoyh7QJZXWJrehL5xJzb
# 18  nPM7KGPb4aCP4b5EPlbxcKRZwp9ZP4h6WJZbN
# 19  WZLWd7ZpJvcBQd17BodGiMoyZ1XyK6hl1BXgG
# 20  Gqy4pgqRwvhXlerwXLeNc5eQdrXQ3xf1PZq3Q
# 21  AgxzeZg418tyJazbyNa1TNjLmygLQqF1ABaPz
# 22  WZLWd7ZpJvcBQd17BodGiMoyZ1XyK6hl1BXEn
# 23  EAwd1pAn7GFbAjqvbDjKsxGLNqjLa6iXk6rlo
# 24  7janBxjLP7tlg8xelk8ZFmVqyxeqaEFgnw6mZ
# 25  EAwd1pAn7GFbAjqvbDjKsxGLNqjLa6iXk6rbq
# 26  dKDzpkKNgvcGnvyMGzv8SDKd1P6dG7cZQXlaP
# 27  DW1kMLW4oATDePl1DLPntQ5ZMlXZL8HvaZ7kj
# 28  87Db3d7v6ehv9lWEvKlRcq1EBvXEbQfwLNgLd
# 29  87Db3d7v6ehv9lWEvKlRcq1EBvXEbQfwLNgqo
# 30  Gqy4pgqRwvhXlerwXLeNc5eQ4W6gMgS1PZqkx
# 31  nPM7KGPb4aCP4b5EPlbxcKRZ1WvmemH6WJZvl
# 32  AgxzeZg418tyJazbyNa1TNjLDbPBlBC1ABazL
# 33  jdJ4A9dkpBcGebg6G4b5SZdaDWzaG1C1LQxB5
# 34  gBPx8GBNpKuBAwRmB5wai4r1pme1GDcgnyPnA
# 35  WZLWd7ZpJvcBQd17BodGiMoy8zjEVEsl1BXgQ
# 36  ojJerGjWb4tjmbRajqboIkDlEN9ljaFR7v17W
# 37  p7PQzy7lgNhGARPvGKReSE74W5X4y1tLVXbV7
# 38  L34eWr3QMvhyBLdAykLDTyvL5dELaVcPp3qpv
# 39  1x4gGqxLJdurLQaVrRQdhdKNLraNAqu5eDNev
# 40  P4Q1qx4jrvFoanPAoDnJhRz6gPW6vMc7WK89M
# 41  EAwd1pAn7GFbAjqvbDjKsxGLovAJmJCXk6rbm
# 42  xog8PGoRx1SoJm6go4mjhJloqDEonvtnVQkBm
# 43  XMgAaeMQovTjZmLwjgmkIkGxzwLxv5FdnD93w
# 44  MxjQAzxRlvu73paK7Ap6hKn7ram7yBh9PmNPG
# 45  87Db3d7v6ehv9lWEvKlRcq1Ez5VrkriwLNgqm
# 46  ojJerGjWb4tjmbRajqboIkDlzGxXMXcR7v1E8
# 47  gBPx8GBNpKuBAwRmB5wai4r1587A9ACgnyPWn
# 48  p7PQzy7lgNhGARPvGKReSE74JoaprpHLVXbaN

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
# YOUR CODE HERE

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Calculate the expenses per month

# %%
# YOUR CODE HERE
